# %% [markdown]
# <a href="https://colab.research.google.com/github/iancamleite/trials/blob/master/Analysis_Trials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Como executar este report:
#
# 1. No menu superior, encontre a aba **Runtime** e selecione a opção **Run All** e em seguida **RUN ANYWAY**.
# 2. Clique na seta ao lado do título **Importing data** abaixo deste texto e em seguida **Deseja mudar o arquivo?** para escolher se deseja manter o arquivo csv ou atualizá-lo. Caso escolha a opção 1, clique também em **Changing File** e então escolha um arquivo do seu computador.
# 3. Clique na seta ao lado do título **Plots** para ver o report.
# 4. Ao finalizar a visualização, ir em **Runtime** e **Restartart Runtime**.
#
# ### Boa análise!

# %% [markdown]
# # Importing data

# %% [markdown]
# ### Setting up

# %%
import pandas as pd

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/iancamleite/trials/master/exercicio_2.csv')

# %% [markdown]
# ### Deseja mudar o arquivo?

# %%
in_csv = input('Deseja mudar o arquivo csv ou continuar com https://raw.githubusercontent.com/iancamleite/trials/master/exercicio_2.csv ? \n\nResponda com 1 para mudar de arquivo ou 2 para continuar com o existente:')
# Out:
# Deseja mudar o arquivo csv ou continuar com https://raw.githubusercontent.com/iancamleite/trials/master/exercicio_2.csv ?
#
# Responda com 1 para mudar de arquivo ou 2 para continuar com o existente:1

# %% [markdown]
# ### Changing file

# %%
if in_csv in ['1', '2']:
  if in_csv in ['1']: 
    from google.colab import files
    upload = files.upload()
    upload_name = list(upload.keys())[0]
    import io
    df = pd.read_csv(io.BytesIO(upload[upload_name])) 
  elif in_csv in ['2']:
    df = pd.read_csv('https://raw.githubusercontent.com/iancamleite/trials/master/exercicio_2.csv')
else:
  in_csv = input('Por favor, insira uma opção válida: \n\n- Insira 1 para mudar o arquivo csv ou \n\n- Insira 2 para manter o arquivo https://raw.githubusercontent.com/iancamleite/trials/master/exercicio_2.csv')
# Out:
#      <input type="file" id="files-f11082e0-b35a-432f-9a19-7f605386a950" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f11082e0-b35a-432f-9a19-7f605386a950">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exercicio_2.csv to exercicio_2 (1).csv

# %% [markdown]
# # Development

# %% [markdown]
# ## Structuring Data

# %%
df
# Out:
#        amplitude_id  user_id  ... gp:utm_term          gp:vertical
# 0       20647856536   465842  ...         NaN                gifts
# 1       20657540168   469775  ...         NaN          food_drinks
# 2       20988792792   468699  ...         NaN             clothing
# 3       20989373128   465625  ...         NaN          home_garden
# 4       20990548904   465640  ...         NaN             clothing
# ...             ...      ...  ...         ...                  ...
# 11454   23013205990   483433  ...         NaN  clothing_accesories
# 11455   23013961590   483441  ...         NaN                  NaN
# 11456   23018926998   483488  ...         NaN                  NaN
# 11457   23021480934   483526  ...         NaN        health_beauty
# 11458   23021853190   483534  ...         NaN             clothing
#
# [11459 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['amplitude_id', 'user_id', 'carrier', 'city', 'country', 'device',
#        'device_type', 'dma', 'language', 'library', 'os', 'paying', 'platform',
#        'region', 'start_version', 'version', 'gp:brick_and_mortars',
#        'gp:business_size', 'gp:chat', 'plan_context', 'gp:country',
#        'gp:created_at', 'gp:first_contact', 'gp:from', 'gp:initial_referrer',
#        'gp:initial_referring_domain', 'gp:initial_utm_campaign',
#        'gp:initial_utm_content', 'gp:initial_utm_medium',
#        'gp:initial_utm_source', 'gp:initial_utm_term', 'gp:new_billing_flow',
#        'gp:new_product_filter', 'gp:orders', 'gp:products', 'gp:referrer',
#        'gp:referring_domain', 'gp:source', 'gp:store_id', 'gp:theme',
#        'gp:trial_payment_bar', 'gp:utm_campaign', 'gp:utm_content',
#        'gp:utm_medium', 'gp:utm_source', 'gp:utm_term', 'gp:vertical'],
#       dtype='object')

# %%
df.describe()
# Out:
#        amplitude_id        user_id     gp:orders   gp:products    gp:store_id
# count  1.145900e+04   11459.000000  11147.000000  11147.000000   11459.000000
# mean   2.203281e+10  474506.518195      3.128465     10.794833  474510.063007
# std    6.777667e+08    5287.557632     81.682085    133.295389    5303.074034
# min    1.010941e+10  465625.000000      0.000000      0.000000  465625.000000
# 25%    2.152034e+10  469849.000000      0.000000      0.000000  469849.000000
# 50%    2.210804e+10  474527.000000      0.000000      0.000000  474527.000000
# 75%    2.255180e+10  479086.500000      0.000000      1.000000  479087.500000
# max    2.344101e+10  483559.000000   5057.000000   9797.000000  517995.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11459 entries, 0 to 11458
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   amplitude_id                 11459 non-null  int64
#  1   user_id                      11459 non-null  int64
#  2   carrier                      362 non-null    object
#  3   city                         11060 non-null  object
#  4   country                      11442 non-null  object
#  5   device                       11459 non-null  object
#  6   device_type                  1854 non-null   object
#  7   dma                          80 non-null     object
#  8   language                     11168 non-null  object
#  9   library                      11459 non-null  object
#  10  os                           2003 non-null   object
#  11  paying                       11459 non-null  bool
#  12  platform                     11459 non-null  object
# ...

# %%
df.dtypes
# Out:
# amplitude_id                     int64
# user_id                          int64
# carrier                         object
# city                            object
# country                         object
# device                          object
# device_type                     object
# dma                             object
# language                        object
# library                         object
# os                              object
# paying                            bool
# platform                        object
# region                          object
# start_version                   object
# version                         object
# gp:brick_and_mortars            object
# gp:business_size                object
# gp:chat                         object
# plan_context                    object
# gp:country                      object
# gp:created_at                   object
# gp:first_contact                object
# gp:from                         object
# ...

# %%
datetime = pd.to_datetime(df["gp:created_at"], format='%m/%d/%Y')

# %%
df['gp:created_at'] = datetime

# %%
df.drop(['carrier','dma','library','os','start_version','version','gp:initial_utm_content','gp:new_product_filter','gp:utm_content','gp:initial_utm_term'], axis=1, inplace=True)

# %%
#df.groupby([df.index, 'gp:initial_utm_campaign']).count().plot(kind='bar')

# %%
df['gp:first_contact'].replace('facebok','facebook', inplace=True)

# %%
df['gp:utm_source'].replace('RD Station','rdstation', inplace=True)

# %%
df['gp:utm_source'].replace('blog','ourblog', inplace=True)

# %%
df['gp:initial_utm_source'].replace('RD Station','rdstation', inplace=True)

# %%
df['gp:initial_utm_source'].replace('blog','ourblog', inplace=True)

# %%
df['gp:utm_source'].replace('facebook.com','facebook', inplace=True)

# %%
df['gp:initial_utm_source'].replace('facebook.com','facebook', inplace=True)

# %% [markdown]
# ## Campaigns Analysis

# %% [markdown]
# ### Processing

# %%
df['gp:initial_utm_campaign']
# Out:
# 0                          comecar-seu-negocio
# 1                                          NaN
# 2                                          NaN
# 3                       warm-site-vendas-sales
# 4                       warm-site-vendas-sales
#                          ...
# 11454                 warm-loja-internet-start
# 11455                 warm-loja-internet-start
# 11456    trial-paying-configure-payment-option
# 11457                                      NaN
# 11458          cold-app-android-lookalike-blog
# Name: gp:initial_utm_campaign, Length: 11459, dtype: object

# %%
s = df.groupby('gp:initial_utm_campaign')['user_id'].agg(lambda x:len(x.unique()))
pd.value_counts(s).plot(kind="bar")

# %%
campaigns = pd.DataFrame({'user_id_count':s})

# %%
campaigns['percentage_of_traffic_from_campaigns'] = campaigns['user_id_count']*100/campaigns.sum()[0]

# %%
campaigns['percentage_of_traffic'] = campaigns['user_id_count']*100/df['user_id'].count()

# %% [markdown]
# #### Output of campaigns analysis

# %%
campaigns_10pc = campaigns[campaigns['percentage_of_traffic_from_campaigns']>10]

# %%
campaigns_10pc
# Out:
#                           user_id_count  ...  percentage_of_traffic
# gp:initial_utm_campaign                  ...
# warm-loja-internet-start           1056  ...               9.215464
# warm-site-vendas-sales              957  ...               8.351514
# warm-vender-online-start            825  ...               7.199581
#
# [3 rows x 3 columns]

# %%
campaigns_5pc = campaigns[campaigns['percentage_of_traffic']>5]

# %% [markdown]
# #### Picking data to plot best campaigns

# %%
import plotly.express as px

# %%
px.bar(campaigns_10pc, 
       x=campaigns_10pc.index,         
       y="user_id_count",  
       title=f"Dentre as campanhas - trouxeram mais de 10% dos trials",
       labels={"user_id_count": "#trials"}, # the axis names
       color_discrete_sequence=["blueviolet"], # the colors used
       height=400,
       width=700)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c19f689c-f1dd-4995-a16f-613f438e3928" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c19f689c-f1dd-4995-a16f-613f438e3928")) {
#                     Plotly.newPlot(
#                         'c19f689c-f1dd-4995-a16f-613f438e3928',
# ...

# %%
px.bar(campaigns_5pc, 
       x=campaigns_5pc.index,         
       y="user_id_count",  
       title=f"Dentre todos os trials - representam mais de 5%",
       labels={"user_id_count": "#trials"}, # the axis names
       color_discrete_sequence=["blueviolet"], # the colors used
       height=400,
       width=700)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="611a5366-41ae-46ed-b4d0-7747da50eff7" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("611a5366-41ae-46ed-b4d0-7747da50eff7")) {
#                     Plotly.newPlot(
#                         '611a5366-41ae-46ed-b4d0-7747da50eff7',
# ...

# %% [markdown]
# #### Preparing data to plot best campaigns

# %%
list(campaigns_10pc.index)
# Out:
# ['warm-loja-internet-start',
#  'warm-site-vendas-sales',
#  'warm-vender-online-start']

# %%
list(campaigns_5pc.index)
# Out:
# ['hot-nuvemshop',
#  'warm-loja-internet-start',
#  'warm-loja-virtual-exata-start',
#  'warm-loja-virtual-start',
#  'warm-site-vendas-sales',
#  'warm-vender-online-start']

# %%
best_campaigns = list(campaigns_10pc.index) + list(campaigns_5pc.index)
best_campaigns
# Out:
# ['warm-loja-internet-start',
#  'warm-site-vendas-sales',
#  'warm-vender-online-start',
#  'hot-nuvemshop',
#  'warm-loja-internet-start',
#  'warm-loja-virtual-exata-start',
#  'warm-loja-virtual-start',
#  'warm-site-vendas-sales',
#  'warm-vender-online-start']

# %%
best_campaigns_set = set(best_campaigns)
best_campaigns_set
# Out:
# {'hot-nuvemshop',
#  'warm-loja-internet-start',
#  'warm-loja-virtual-exata-start',
#  'warm-loja-virtual-start',
#  'warm-site-vendas-sales',
#  'warm-vender-online-start'}

# %%
best_campaigns = list(best_campaigns_set)
best_campaigns
# Out:
# ['warm-loja-virtual-exata-start',
#  'warm-loja-internet-start',
#  'warm-loja-virtual-start',
#  'warm-vender-online-start',
#  'warm-site-vendas-sales',
#  'hot-nuvemshop']

# %%
bc_df = df[df['gp:initial_utm_campaign'].isin(best_campaigns)][['gp:created_at','gp:initial_utm_campaign']]
bc_df
# Out:
#       gp:created_at        gp:initial_utm_campaign
# 3        2020-01-05         warm-site-vendas-sales
# 4        2020-01-05         warm-site-vendas-sales
# 13       2020-01-05       warm-vender-online-start
# 19       2020-01-05        warm-loja-virtual-start
# 21       2020-01-05       warm-loja-internet-start
# ...             ...                            ...
# 11451    2020-05-31  warm-loja-virtual-exata-start
# 11452    2020-05-31                  hot-nuvemshop
# 11453    2020-05-31  warm-loja-virtual-exata-start
# 11454    2020-05-31       warm-loja-internet-start
# 11455    2020-05-31       warm-loja-internet-start
#
# [4924 rows x 2 columns]

# %%
bc_df.rename(columns={"gp:created_at": "Data", "gp:initial_utm_campaign": "Campanha"}, inplace=True)

# %%
bc_df = bc_df.groupby(['Data','Campanha']).size()

# %%
bc_df = pd.DataFrame(bc_df, columns=['Novos Trials'])

# %%
bc_df.reset_index(level=1, inplace=True)

# %%
bc_df
# Out:
#                                  Campanha  Novos Trials
# Data
# 2020-01-05                  hot-nuvemshop            20
# 2020-01-05       warm-loja-internet-start            35
# 2020-01-05  warm-loja-virtual-exata-start            28
# 2020-01-05        warm-loja-virtual-start            27
# 2020-01-05         warm-site-vendas-sales            41
# ...                                   ...           ...
# 2020-12-05       warm-loja-internet-start            26
# 2020-12-05  warm-loja-virtual-exata-start            18
# 2020-12-05        warm-loja-virtual-start            21
# 2020-12-05         warm-site-vendas-sales            25
# 2020-12-05       warm-vender-online-start            24
#
# [189 rows x 2 columns]

# %%
bc_df.sort_values(by=['Data'], inplace=True)

# %%
bc_copy = bc_df.copy()

# %%
bc_df.columns
# Out:
# Index(['Campanha', 'Novos Trials'], dtype='object')

# %%
columns = list(bc_df.columns)
columns.append('Soma Cumulativa dos Trials')
columns
# Out:
# ['Campanha', 'Novos Trials', 'Soma Cumulativa dos Trials']

# %%
bc_df_cumsum = pd.DataFrame(columns=columns)

# %%
for i in best_campaigns:
    df_i = bc_df[bc_df['Campanha']==i].copy()
    df_i['Soma Cumulativa dos Trials'] = df_i['Novos Trials'].cumsum()
    bc_df_cumsum = pd.concat([bc_df_cumsum,df_i])
    bc_df_cumsum

# %%
bc_df_cumsum
# Out:
#                                  Campanha  ... Soma Cumulativa dos Trials
# 2020-01-05  warm-loja-virtual-exata-start  ...                         28
# 2020-02-05  warm-loja-virtual-exata-start  ...                         55
# 2020-03-05  warm-loja-virtual-exata-start  ...                         75
# 2020-04-05  warm-loja-virtual-exata-start  ...                         99
# 2020-05-05  warm-loja-virtual-exata-start  ...                        120
# ...                                   ...  ...                        ...
# 2020-08-05                  hot-nuvemshop  ...                        550
# 2020-09-05                  hot-nuvemshop  ...                        574
# 2020-10-05                  hot-nuvemshop  ...                        598
# 2020-11-05                  hot-nuvemshop  ...                        617
# 2020-12-05                  hot-nuvemshop  ...                        631
#
# [189 rows x 3 columns]

# %% [markdown]
# ## Traffic by source Analysis

# %% [markdown]
# ### Code

# %%
df
# Out:
#        amplitude_id  user_id  ... gp:utm_term          gp:vertical
# 0       20647856536   465842  ...         NaN                gifts
# 1       20657540168   469775  ...         NaN          food_drinks
# 2       20988792792   468699  ...         NaN             clothing
# 3       20989373128   465625  ...         NaN          home_garden
# 4       20990548904   465640  ...         NaN             clothing
# ...             ...      ...  ...         ...                  ...
# 11454   23013205990   483433  ...         NaN  clothing_accesories
# 11455   23013961590   483441  ...         NaN                  NaN
# 11456   23018926998   483488  ...         NaN                  NaN
# 11457   23021480934   483526  ...         NaN        health_beauty
# 11458   23021853190   483534  ...         NaN             clothing
#
# [11459 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11459 entries, 0 to 11458
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   amplitude_id                 11459 non-null  int64
#  1   user_id                      11459 non-null  int64
#  2   city                         11060 non-null  object
#  3   country                      11442 non-null  object
#  4   device                       11459 non-null  object
#  5   device_type                  1854 non-null   object
#  6   language                     11168 non-null  object
#  7   paying                       11459 non-null  bool
#  8   platform                     11459 non-null  object
#  9   region                       11187 non-null  object
#  10  gp:brick_and_mortars         820 non-null    object
#  11  gp:business_size             7875 non-null   object
#  12  gp:chat                      9433 non-null   object
# ...

# %% [markdown]
# Possible columns: gp:first_contact gp:initial_utm_medium gp:initial_utm_source

# %%
source = df.groupby('gp:first_contact')['user_id'].agg(lambda x:len(x.unique()))
pd.value_counts(source).plot(kind="bar")

# %% [markdown]
# #### Output of campaigns analysis

# %%
source_1 = pd.DataFrame({'user_id_count':df.groupby('gp:first_contact')['user_id'].agg(lambda x:len(x.unique()))})

# %%
source_2 = pd.DataFrame({'user_id_count':df.groupby('gp:initial_utm_medium')['user_id'].agg(lambda x:len(x.unique()))})

# %%
source_3 = pd.DataFrame({'user_id_count':df.groupby('gp:initial_utm_source')['user_id'].agg(lambda x:len(x.unique()))})

# %%
source_4 = pd.DataFrame({'user_id_count':df.groupby('gp:source')['user_id'].agg(lambda x:len(x.unique()))})

# %%
source_5 = pd.DataFrame({'user_id_count':df.groupby('gp:vertical')['user_id'].agg(lambda x:len(x.unique()))})

# %%
fig_0 = px.line(bc_df_cumsum, x=bc_df_cumsum.index, y='Soma Cumulativa dos Trials', color='Campanha', title='Desempenho das melhores campanhas', width=1000)
fig_0.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig_1 = px.pie(source_1, values='user_id_count', names=source_1.index, title='First Contact', width=1000, height=500)
fig_1.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig_2 = px.pie(source_2, values='user_id_count', names=source_2.index, title='Initial UTM Medium', width=1000, height=500)
fig_2.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig_3 = px.pie(source_3, values='user_id_count', names=source_3.index, title='Initial UTM Source', width=1000, height=500)
fig_3.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig_4 = px.pie(source_4, values='user_id_count', names=source_4.index, title='Platforma', width=1000, height=500)
fig_4.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig_5 = px.pie(source_5, values='user_id_count', names=source_5.index, title='Setor', width=1000, height=500)
fig_5.update_layout(
    autosize=True,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b9546b7-1b7d-4c92-8bf3-67a80f527c47" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b9546b7-1b7d-4c92-8bf3-67a80f527c47")) {
#                     Plotly.newPlot(
#                         '1b9546b7-1b7d-4c92-8bf3-67a80f527c47',
# ...

# %% [markdown]
# # Plots

# %%
fig_0.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="131b5804-77de-4256-b05b-a7a71199be64" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("131b5804-77de-4256-b05b-a7a71199be64")) {
#                     Plotly.newPlot(
#                         '131b5804-77de-4256-b05b-a7a71199be64',
# ...

# %%
fig_0.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd28b352-2dfb-4297-8d3b-1c3a5127c2ee" class="plotly-graph-div" style="height:525px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd28b352-2dfb-4297-8d3b-1c3a5127c2ee")) {
#                     Plotly.newPlot(
#                         'dd28b352-2dfb-4297-8d3b-1c3a5127c2ee',
# ...

# %%
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54fa62ff-37db-4582-bb25-547004cb7314" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54fa62ff-37db-4582-bb25-547004cb7314")) {
#                     Plotly.newPlot(
#                         '54fa62ff-37db-4582-bb25-547004cb7314',
# ...

# %%
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="126a09a6-1e1f-4fd5-a354-ad6beafd83e2" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("126a09a6-1e1f-4fd5-a354-ad6beafd83e2")) {
#                     Plotly.newPlot(
#                         '126a09a6-1e1f-4fd5-a354-ad6beafd83e2',
# ...

# %%
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="46092c5d-e1fc-4ecb-a4ac-53b28990e1ef" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46092c5d-e1fc-4ecb-a4ac-53b28990e1ef")) {
#                     Plotly.newPlot(
#                         '46092c5d-e1fc-4ecb-a4ac-53b28990e1ef',
# ...

# %%
fig_4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6eba1a1e-9349-4083-9543-cb71280f37ae" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6eba1a1e-9349-4083-9543-cb71280f37ae")) {
#                     Plotly.newPlot(
#                         '6eba1a1e-9349-4083-9543-cb71280f37ae',
# ...

# %%
fig_5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16a21d06-5957-4330-aca8-9b71e3f4da02" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16a21d06-5957-4330-aca8-9b71e3f4da02")) {
#                     Plotly.newPlot(
#                         '16a21d06-5957-4330-aca8-9b71e3f4da02',
# ...
